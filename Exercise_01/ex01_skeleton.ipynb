# %% [markdown]
# # Exercise 01 — Introduction to Google Colab
#
# MSc Finance · Investments · FHNW · Autumn 2026
#
# Three asset classes, a century of annual returns, and the four things you will do in every
# later exercise: describe, regress, plot, export.
#
# **How to work with this notebook.** The task text is on the exercise sheet; the headings
# here match it. Each code cell is a stub: the `# TODO` lines are the steps, in order, and
# you replace each one with the code that does it. The setup cell below is complete — run it
# first and leave it alone. Names you will need (`DATA_URL`, `SHEET`, `EQUITY`, `SMALL`,
# `BOND`, `BILL`, `ASSETS`) are already defined there.
#
# Run **Runtime → Restart and run all** before you trust any number in here.

# %%
# !wget -q https://raw.githubusercontent.com/KroeTiA/Investments/main/exercise_utils.py

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

from exercise_utils import setup_style, load_returns, save_results
setup_style()

SEED = 42   # every notebook in this course fixes its seed; nothing is random this week

BASE = "https://raw.githubusercontent.com/KroeTiA/Investments/main/"
DATA_URL = BASE + "Exercise_01/data/histretSP_investments.xlsx"
SHEET = "Total Return Index_Damadoran"

EQUITY = "S&P 500 (includes dividends)"
SMALL = "US Small cap (bottom decile)"
BOND = "US T. Bond"
BILL = "3-month T.Bill"
ASSETS = [EQUITY, BOND, BILL]

print("Setup complete.")

# %% [markdown]
# ## B1 — Reproduce your Part A numbers
#
# The five returns from **Part A** of the sheet: +25 %, −20 %, +15 %, −5 %, +10 %. Compute the
# arithmetic mean, the geometric mean and the sample standard deviation in code, and check
# them against what you got on paper.

# %%
# TODO: put the five Part A returns into a pandas Series called `a`
# TODO: arithmetic mean, geometric mean and sample standard deviation of `a`

# %% [markdown]
# ## B2 — Load the data and describe it
#
# Load the Damodaran total-return indices, keep the S&P 500, US T. Bonds and 3-month T-Bills,
# and report the arithmetic mean, the geometric mean and the standard deviation for the full
# sample and for 1990 onwards. Same three operations as in B1, now on 98 observations.

# %%
# TODO: load the index levels and the annual returns, then keep ASSETS only
# TODO: replace the ... below with the body: return the three statistics for one return table
def stats(r):
    ...
# TODO: apply it to the full sample and to 1990 onwards, and print both

# %% [markdown]
# ## B3 — Two regressions
#
# Regress the excess return of small-cap stocks on the excess return of the S&P 500, then do
# the same for US T. Bonds. Excess means in excess of the 3-month T-Bill, on both sides.
# Report the intercept, the slope and R² for each.

# %%
# TODO: build a table of excess returns over the T-Bill
# TODO: regress each of small caps and bonds on the S&P 500; print intercept, slope, R-squared

# %% [markdown]
# ## B4 — One figure and the export
#
# Draw the two regressions, and export the figure together with your B2 table. You choose the
# axes; the aim is a figure that would stand on its own in an exam answer.

# %%
# TODO: scatter each asset against the S&P 500 excess return and add the fitted line
# TODO: export the figure and the B2 table

# %% [markdown]
# ## Part C
#
# Part C is on the sheet. It asks about the gap between the arithmetic and the geometric mean
# in your B2 table, and it is answered in prose, not in code. Bring your answer to the
# discussion in week 2.
